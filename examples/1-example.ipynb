# %% [markdown]
# # The Demo of $S^2$Generator for Series-Symbol Data Generation
#
# Time series data serves as the external manifestation of complex dynamical systems. This method aims to generate diverse complex systems represented by symbolic expressions $f(\cdot)$ — through unconstrained construction. It simultaneously generates excitation time series $X \in \mathbb{R} ^ {M \times L}$, which are then fed into the complex systems to produce their responses $Y=f(X) \in \mathbb{R} ^ {N \times L}$. Here, $M$, $N$ and $L$ denote the number of input channels, output channels, and series length, respectively.

# %%
import numpy as np
import sys
import os
sys.path.append(os.path.abspath(".."))  # 添加上一级目录到模块搜索路径
# Importing data generators, parameter controllers and visualization functions
from S2Generator import Generator, Params, plot_series, print_hello

print_hello()
# Out:
# Hello, S2Generator!
# ==============================
# This is a Python package for generating time series data with symbolic representations.
# For more information, please visit: https://github.com/wwhenxuan/S2Generator
#
#    _____   ___     _____                                        _
#   / ____| |__ \   / ____|                                      | |
#  | (___      ) | | |  __    ___   _ __     ___   _ __    __ _  | |_    ___    _ __
#   \___ \    / /  | | |_ |  / _ \ | '_ \   / _ \ | '__|  / _` | | __|  / _ \  | '__|
#   ____) |  / /_  | |__| | |  __/ | | | | |  __/ | |    | (_| | | |_  | (_) | | |
#  |_____/  |____|  \_____|  \___| |_| |_|  \___| |_|     \__,_|  \__|  \___/  |_|

# %%
params = Params()  # Adjust the parameters here
generator = Generator(params)  # Create an instance

rng = np.random.RandomState(0)  # Creating a random number object
# Start generating symbolic expressions, sampling and generating series

# no differential parameter
trees, x, y = generator.run(rng, input_dimension=1, output_dimension=1, n_points=256)
# Print the expressions
print(trees)

# Visualize the time series
fig = plot_series(x, y)
# Out:
# (73.5 add (sin((-7.57 add (3.89 mul x_0))) mul (((-0.092 mul exp((-63.4 add (-0.204 mul x_0)))) add (-6.12 mul log((-0.847 add (9.55 mul x_0))))) sub ((4.49 mul inv((-29.3 add (-86.2 mul x_0)))) add (-2.57 mul sqrt((51.3 add (-55.6 mul x_0))))))))

# %%
# use differential parameter
params = Params()  # Adjust the parameters here
generator = Generator(params)  # Create an instance

rng = np.random.RandomState()  # Creating a random number object
# Start generating symbolic expressions, sampling and generating series

trees, x, y = generator.run(rng, input_dimension=1, output_dimension=1, n_points=256, diff=1)
# Print the expressions
print(trees)

# Visualize the time series
fig = plot_series(x, y)
# Out:
# (-10.9 add (20.0 mul x_0))

# %%
rng = np.random.RandomState(44)  # Change the random seed

# Try to generate the multi-channels time series
trees, x, y = generator.run(rng, input_dimension=2, output_dimension=2, n_points=256,diff=1)
print(trees)
fig = plot_series(x, y)
# Out:
# (-88.7 add (((-53.4 mul sin((0.636 add (-2.5 mul x_0)))) sub (-4.62 mul x_1)) sub ((-64.5 mul (x_1 mul x_1)) sub (-7.68 mul x_0)))) | (-3.12 add ((12.8 mul abs(((0.583 mul sqrt((0.21 add (-9.92 mul (sqrt((-3.41 add (-89.7 mul x_1))) mul x_0))))) sub (20.1 mul sqrt((-0.965 add (-24.0 mul x_1))))))) add (10.0 mul ((9.19 add (-0.878 mul x_1)))**2)))

# %%
fig.savefig("../images/ID2_OD2.jpg", dpi=300, bbox_inches="tight")

# %%
# Try to generate the 3-channels time series
trees, x, y = generator.run(rng, input_dimension=3, output_dimension=3, n_points=256, diff=1)
print(trees)
fig = plot_series(x, y)
# Out:
# (-4.92 add (((-0.145 add (-0.233 mul x_0)))**3 mul ((-4.75 add (52.5 mul x_1)))**2)) | (0.338 add ((-2.76 mul x_2) add ((-4.6 mul inv((94.3 add (58.2 mul x_1)))) add (-1.17 mul (x_2 mul inv((0.049 add (4.5 mul (x_0 mul inv((4.51 add (6.13 mul (((-10.7 add (92.5 mul x_1)))**2 mul ((0.805 add (-86.7 mul x_2)))**3))))))))))))) | (-9.1 add (44.5 mul x_0))

# %%
fig.savefig("../images/ID3_OD3.jpg", dpi=300, bbox_inches="tight")
